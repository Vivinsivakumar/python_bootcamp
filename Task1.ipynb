# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivinsivakumar/python_bootcamp/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1
name = "Vivin"
print(name)

# 2
a = 10
b = 20
a, b = b, a
print(a, b)

# 3
x, y, z = 1, 2, 3
print(x + y + z)

# 4
num = 100
print("Before:", num)
num = 200
print("After:", num)

# 5
val = 50
del val
# print(val)  # This will raise NameError
# Out:
# Vivin
# 20 10
# 6
# Before: 100
# After: 200

# %%
# 1
a = 10
b = 3.14
c = "Hello"
d = True

print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))

# 2
print(type(3.14))
print(type("Hello"))
print(type(True))
print(type(0))

# 3
x = 9
print(isinstance(x, int))

# 4
print(type(None))

# 5
big_int = 123456789123456789123456789
small_float = 0.000000000123
print(big_int)
print(small_float)
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>
# Hello <class 'str'>
# True <class 'bool'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'int'>
# True
# <class 'NoneType'>
# 123456789123456789123456789
# 1.23e-10

# %%
# 1
num = int("123")
print(num + 7)

# 2
print(int(9.99))  # decimal is truncated (removed)

# 3
print(bool(0))
print(bool(1))

# 4
print(int(True))
print(int(False))

# 5
user_input = float(input("Enter a number: "))
print(user_input * 2)

# 6
# int("hello")  # ValueError: invalid literal for int()
# Out:
# 130
# 9
# False
# True
# 1
# 0
# Enter a number: 56
# 112.0

# %%
# 1
s = "Hello, World!"
print(s.upper())
print(s.lower())

# 2
print(len("Python Programming"))

# 3
print(s[7:12])  # World

# 4
print("abcdef"[::-1])

# 5
print("nan" in "banana")

# 6
print("This is a bad day".replace("bad", "good"))

# 7
print(" hello ".strip())

# 8
print("apple,banana,cherry".split(","))

# 9
print("banana".count("a"))

# 10
print("Python123".isalnum())
# Out:
# HELLO, WORLD!
# hello, world!
# 18
# World
# fedcba
# True
# This is a good day
# hello
# ['apple', 'banana', 'cherry']
# 3
# True

# %%
# 1
name = "John"
age = 25
print(f"My name is {name} and I am {age} years old")

# 2
price = 49.99
print("The price is {} dollars".format(price))

# 3
print(f"{3.14159:.2f}")

# 4
print(f"{7:03}")

# 5
a, b = 5, 3
print(f"{a} x {b} = {a*b}")

# 6
names = ["Alice", "Bob", "Charlie"]
scores = [90, 85, 95]

for i in range(len(names)):
    print(f"{names[i]:<10} {scores[i]:>5}")
# Out:
# My name is John and I am 25 years old
# The price is 49.99 dollars
# 3.14
# 007
# 5 x 3 = 15
# Alice         90
# Bob           85
# Charlie       95

# %%
# 1
fruits = ["apple", "banana", "cherry", "mango", "orange"]
print(fruits)

# 2
lst = [10, 20, 30, 40, 50]
print(lst[0])
print(lst[-1])

# 3
fruits.append("grape")
print(fruits)

# 4
lst.insert(2, 99)
print(lst)

# 5
fruits.remove("banana")
print(fruits)

# 6
nums = [5, 2, 8, 1, 9]
print(sorted(nums))
print(sorted(nums, reverse=True))

# 7
nums = [3, 7, 1, 9, 4]
print(len(nums))
print(max(nums))
print(min(nums))

# 8
lst = [0, 1, 2, 3, 4, 5, 6]
print(lst[2:5])

# 9
original = [1, 2, 3]
copy_list = original.copy()
copy_list.append(4)
print("Original:", original)
print("Copy:", copy_list)

# 10
list1 = [1, 2, 3]
list2 = [4, 5, 6]
merged = list1 + list2
print(merged)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange']
# 10
# 50
# ['apple', 'banana', 'cherry', 'mango', 'orange', 'grape']
# [10, 20, 99, 30, 40, 50]
# ['apple', 'cherry', 'mango', 'orange', 'grape']
# [1, 2, 5, 8, 9]
# [9, 8, 5, 2, 1]
# 5
# 9
# 1
# [2, 3, 4]
# Original: [1, 2, 3]
# Copy: [1, 2, 3, 4]
# [1, 2, 3, 4, 5, 6]
